# %% [markdown]
# # Initialization

# %%
# %%time

# %matplotlib inline
import os
import sys
import datetime
import re
import collections

import json
import pickle
import urllib
import pandas as pd
import numpy as np

from collections import OrderedDict
from gspread import WorksheetNotFound
from bs4 import BeautifulSoup
from oauth2client.service_account import ServiceAccountCredentials

pd.set_option("display.max_columns", 100)

DATETIME_STRING_FORMAT = '%Y-%m-%d %H:%M:%S'

# Tables to retrieve for each player, by table html ids
TABLE_IDS = [
    'per_game',
    'totals',
    'per_minute',  # per 36 minutes
    'per_poss',  # per 100 possessions
    'advanced',  # advanced
    'playoffs_per_game',
    'playoffs_totals',
    'playoffs_per_minute',  # playoffs per 36 minutes
    'playoffs_per_poss',  # playoffs per 100 possessions
    'playoffs_advanced',
    'all_star',
    'all_college_stats',
    'all_salaries',
]

print('Current TABLE_IDS length: ', len(TABLE_IDS))
# Out:
# Current TABLE_IDS length:  13
# CPU times: user 1.72 s, sys: 384 ms, total: 2.1 s
# Wall time: 2.34 s

# %%
# %%time

test = {
    'words':
    """
        Lorem ipsum dolor sit amet, consectetur adipiscing 
        elit. Mauris adipiscing adipiscing placerat. 
        Vestibulum augue augue, 
        pellentesque quis sollicitudin id, adipiscing.
        """,
    'list':
    list(range(10000)),
    'dict':
    dict((str(i), 'a') for i in range(10000)),
    'int':
    100,
    'float':
    100.123456
}


def sizeof_fmt(num, suffix='B'):
    for unit in ['', 'Ki', 'Mi', 'Gi', 'Ti', 'Pi', 'Ei', 'Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)


def get_file_size(filename):
    statinfo = os.stat(filename)
    return sizeof_fmt(statinfo.st_size)


def save_pickle(item, filename):
    with open(filename, 'wb') as file:
        pickle.dump(item, file)
    print('\n'
          'SAVED  > ', filename, ' | ',
          get_file_size(filename), ' | ', 'length: ', len(item), '\n')
    return True


def load_pickle(filename):
    with open(filename, 'rb') as file:
        obj = pickle.load(file)
        print('\n'
              'LOADED > ', filename, ' | ',
              get_file_size(filename), ' | ', 'length: ', len(obj), '\n')
        return obj


save_pickle(test, 'test.pickle')

len(load_pickle('test.pickle'))
# Out:
# SAVED  >  test.pickle  |  183.8 KiB  |  length:  5
#
#
# LOADED >  test.pickle  |  183.8 KiB  |  length:  5
#
# CPU times: user 12.3 ms, sys: 3.84 ms, total: 16.2 ms
# Wall time: 14.4 ms

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Load Data

# %%
# all_players_stats is a dictionary
# all_players_stats{"table_name": dataframe}, dataframe has player_name as indices
# all_players_stats['advanced'].loc['yao ming'] would return Yao Ming's advanced stats

all_players_stats = load_pickle('all_players_dfs.pickle')
# Out:
# LOADED >  all_players_dfs.pickle  |  57.4 MiB  |  length:  15

# %%
all_players_stats['totals'].loc['yao ming']
# Out:
#              2P    2P%     2PA   3P  3P%   3PA    AST   Age    BLK     DRB  \
# Season
# 2002-03   400.0  0.498   803.0  1.0  0.5   2.0  137.0  22.0  147.0   479.0
# 2003-04   535.0  0.523  1023.0  0.0  0.0   2.0  122.0  23.0  156.0   538.0
# 2004-05   538.0  0.552   975.0  0.0  NaN   0.0   61.0  24.0  160.0   461.0
# 2005-06   467.0  0.519   899.0  0.0  0.0   1.0   85.0  25.0   94.0   433.0
# 2006-07   423.0  0.518   817.0  0.0  0.0   2.0   94.0  26.0   94.0   351.0
# 2007-08   432.0  0.508   850.0  0.0  0.0   2.0  129.0  27.0  111.0   422.0
# 2008-09   565.0  0.548  1031.0  1.0  1.0   1.0  137.0  28.0  150.0   557.0
# 2010-11    18.0  0.486    37.0  0.0  NaN   0.0    4.0  30.0    8.0    20.0
# Career   3378.0  0.525  6435.0  2.0  0.2  10.0  769.0   NaN  920.0  3261.0
#
#              FG    FG%     FGA      FT    FT%     FTA      G     GS   Lg  \
# Season
# 2002-03   401.0  0.498   805.0   301.0  0.811   371.0   82.0   72.0  NBA
# 2003-04   535.0  0.522  1025.0   361.0  0.809   446.0   82.0   82.0  NBA
# 2004-05   538.0  0.552   975.0   389.0  0.783   497.0   80.0   80.0  NBA
# 2005-06   467.0  0.519   900.0   337.0  0.853   395.0   57.0   57.0  NBA
# 2006-07   423.0  0.516   819.0   356.0  0.862   413.0   48.0   48.0  NBA
# 2007-08   432.0  0.507   852.0   345.0  0.850   406.0   55.0   55.0  NBA
# 2008-09   566.0  0.548  1032.0   381.0  0.866   440.0   77.0   77.0  NBA
# 2010-11    18.0  0.486    37.0    15.0  0.938    16.0    5.0    5.0  NBA
# Career   3380.0  0.524  6445.0  2485.0  0.833  2984.0  486.0  476.0  NBA
#
#               MP     ORB      PF     PTS  Pos    STL     TOV     TRB   Tm  \
# Season
# 2002-03   2382.0   196.0   230.0  1104.0    C   31.0   173.0   675.0  HOU
# 2003-04   2692.0   197.0   273.0  1431.0    C   22.0   204.0   735.0  HOU
# 2004-05   2447.0   208.0   298.0  1465.0    C   34.0   196.0   669.0  HOU
# 2005-06   1949.0   148.0   195.0  1271.0    C   30.0   147.0   581.0  HOU
# 2006-07   1624.0   101.0   159.0  1202.0    C   17.0   167.0   452.0  HOU
# 2007-08   2044.0   172.0   171.0  1209.0    C   25.0   183.0   594.0  HOU
# 2008-09   2589.0   204.0   257.0  1514.0    C   30.0   234.0   761.0  HOU
# 2010-11     91.0     7.0    13.0    51.0    C    0.0     7.0    27.0  HOU
# Career   15818.0  1233.0  1596.0  9247.0  NaN  189.0  1311.0  4494.0  NaN
#
#           eFG%
# Season
# 2002-03  0.499
# 2003-04  0.522
# 2004-05  0.552
# 2005-06  0.519
# 2006-07  0.516
# 2007-08  0.507
# 2008-09  0.549
# 2010-11  0.486
# Career   0.525

# %%
# all_players_attributes is an ordered dictionary
# all_players_attributes{"player_name": {'attribute_name': attribute_value}}, 
# all_players_attributes['yao ming']['birth_date'] would return Yao Ming's birth-date

all_players_attributes = load_pickle('all_players_attributes.pickle')

print(all_players_attributes['kobe bryant'].keys())
# Out:
# LOADED >  all_players_attributes.pickle  |  5.9 MiB  |  length:  3997
#
# dict_keys(['twitter', 'missing_attributes', 'nba_debut', 'high_school', 'birth_place', 'url', 'draft', 'shooting_hand', 'numbers', 'birth_date', 'position', 'relatives', 'nicknames', 'height', 'honors', 'chinese_name', 'transactions', 'weight'])

# %%
all_players_attributes['kobe bryant']['missing_attributes']
# Out:
# ['college', 'recruiting_rank']

# %%
all_players_stats['advanced'].loc[(slice(None), '2002-03'), :]
# Out:
#                               3PAr  AST%   Age  BLK%   BPM  DBPM  DRB%  DWS  \
#                     Season
# aaron mckie         2002-03  0.168  18.6  30.0   0.3   1.4   1.4  14.5  3.0
# aaron williams      2002-03  0.002   9.0  31.0   2.7  -1.0   1.3  13.9  2.4
# adam harrington     2002-03  0.378  18.0  22.0   0.7  -7.1  -3.2   7.5  0.1
#                     2002-03  0.176   7.8  22.0   2.0 -12.6  -2.9   6.0  0.0
#                     2002-03  0.550  23.0  22.0   0.0  -4.4  -3.4   8.3  0.0
# adonal foyle        2002-03  0.003   3.1  27.0   7.6   1.5   2.7  18.5  1.7
# adrian griffin      2002-03  0.071  11.0  28.0   0.3   0.9   2.0  14.1  1.9
# aj guyton           2002-03  0.250  28.7  24.0   0.0 -22.4  -6.0   0.0  0.0
# al harrington       2002-03  0.051   8.8  22.0   1.0  -1.8   0.2  15.7  3.2
# alan henderson      2002-03  0.006   4.5  30.0   1.5  -3.0  -0.9  17.8  1.1
# allan houston       2002-03  0.307  13.2  31.0   0.2   0.2  -3.1   7.9  0.6
# allen iverson       2002-03  0.156  25.1  27.0   0.3   2.8  -0.3   9.5  4.2
# alton ford          2002-03  0.000   4.9  21.0   0.0 -13.6  -2.6  22.1  0.0
# alvin williams      2002-03  0.161  27.7  28.0   0.6   0.1  -1.4   8.6  1.2
# amal mccaskill      2002-03  0.000  10.8  29.0   1.0  -4.5   0.6  23.5  0.1
# amare stoudemire    2002-03  0.012   5.0  20.0   2.5  -1.1   0.4  20.9  3.6
# andre miller        2002-03  0.116  31.3  26.0   0.3  -0.5  -1.4   9.0  1.0
# andrei kirilenko    2002-03  0.178  10.6  21.0   6.1   6.6   4.0  14.4  3.8
# andrew declercq     2002-03  0.000   6.2  29.0   2.0  -1.4   0.6  17.5  1.3
# anfernee hardaway   2002-03  0.127  21.5  31.0   1.1   0.0   1.0  12.3  1.9
# ansu sesay          2002-03  0.000   8.1  26.0   0.9  -5.0   0.0  10.4  0.4
# antawn jamison      2002-03  0.142   8.6  26.0   0.9   0.3  -2.4  12.5  0.3
# anthony carter      2002-03  0.034  37.9  27.0   0.4  -5.3  -0.5   9.3  1.1
# anthony goldwire    2002-03  0.360   7.5  31.0   0.0  -7.8  -2.3   8.1  0.1
#                     2002-03  0.444   9.3  31.0   0.0  -7.3  -1.3   6.5  0.1
#                     2002-03  0.143   5.0  31.0   0.0  -8.5  -3.9  10.5  0.0
# anthony johnson     2002-03  0.152  16.7  28.0   0.4  -2.4  -0.2   8.8  1.3
# anthony mason       2002-03  0.003  14.6  36.0   0.4  -0.9   0.0  18.1  0.6
#                     2002-03  SG   1.4  10.1   3.0  0.308  DAL  24.4  -0.1
#                     2002-03  SG   0.7   0.0   4.7  0.455  DEN  12.5   0.0
# adonal foyle        2002-03   C   1.1  15.7  14.6  0.563  GSW  11.0   1.6
# adrian griffin      2002-03  SG   2.9  11.8  10.6  0.463  DAL  13.2   1.0
# aj guyton           2002-03  PG   5.7  20.0   0.0  0.000  GSW  23.6   0.0
# al harrington       2002-03  SF   1.5  13.8  11.6  0.493  IND  21.6   0.1
# alan henderson      2002-03   C   1.2  13.6  15.2  0.508  ATL  13.8  -0.4
# allan houston       2002-03  SG   0.9   9.8   4.4  0.563  NYK  27.0   1.7
# allen iverson       2002-03  SG   3.4  11.2   5.8  0.500  PHI  32.9   4.2
# alton ford          2002-03  PF   0.0  16.2  10.9  0.339  PHO  17.8  -0.1
# alvin williams      2002-03  PG   2.2  11.2   5.3  0.508  TOR  19.7   1.4
# amal mccaskill      2002-03   C   2.3   9.6  17.9  0.293  ATL  13.6   0.0
# amare stoudemire    2002-03  PF   1.3  15.3  15.9  0.530  PHO  21.5   0.6
# andre miller        2002-03  PG   1.8  15.8   6.1  0.495  LAC  20.3   1.1
# andrei kirilenko    2002-03  SF   2.9  14.5  11.5  0.598  UTA  19.6   4.8
# andrew declercq     2002-03   C   1.5  20.5  14.6  0.562  ORL  13.8   0.2
# anfernee hardaway   2002-03  SG   1.9  19.1   8.2  0.499  PHO  19.2   0.9
# ansu sesay          2002-03  SF   1.7  17.7   9.6  0.404  SEA  14.8  -0.3
# antawn jamison      2002-03  SF   1.2   9.5   9.5  0.542  GSW  24.5   1.9
# anthony carter      2002-03  PG   2.7  24.1   5.3  0.390  MIA  17.3  -0.8
# anthony goldwire    2002-03  PG   1.9  17.6   4.1  0.445  TOT  18.7  -0.1
#                     2002-03  PG   3.1   9.6   3.4  0.318  SAS  19.0  -0.1
#                     2002-03  PG   0.0  30.3   5.2  0.707  WAS  18.3  -0.1
# anthony johnson     2002-03  PG   2.3  13.5   5.3  0.512  NJN  16.3  -0.1
# anthony mason       2002-03   C   0.8  15.1  11.5  0.524  MIL  11.5   0.6
# anthony peeler      2002-03  SG   1.7  11.5   6.1  0.499  MIN  14.4   0.9
# antoine rigaudeau   2002-03  SG   1.7  14.6   4.8  0.243  DAL  20.4  -0.2
# ...                          ..   ...   ...   ...    ...  ...   ...   ...
# tracy murray        2002-03  SF   1.3  15.7   6.7  0.407  LAL  20.4  -0.3
# travis best         2002-03  PG   1.3  14.3   4.7  0.473  MIA  19.4  -0.4
# travis knight       2002-03   C   1.5  12.4  12.7  0.424  NYK  13.0  -0.1
# tremaine fowlkes    2002-03  SF   2.3  11.5  10.2  0.533  LAC  13.7   0.1
# trenton hassell     2002-03  SG   1.2  16.6   7.0  0.411  CHI  11.1  -0.6
# troy hudson         2002-03  PG   1.2  14.7   4.0  0.531  MIN  21.6   0.6
# troy murphy         2002-03  PF   1.3  11.2  17.1  0.526  GSW  16.7   0.8
# tyrone hill         2002-03  PF   1.8  16.6  16.5  0.457  TOT  13.3  -0.5
#                     2002-03  PF   1.9  19.3  17.5  0.468  CLE  13.7  -0.4
#                     2002-03  PF   1.6  11.4  14.7  0.438  PHI  12.7  -0.1
# tyronn lue          2002-03  PG   1.3  11.1   4.4  0.523  WAS  16.5   0.0
# tyson chandler      2002-03   C   1.0  18.1  15.5  0.565  CHI  18.1   0.8
# vin baker           2002-03   C   1.2  19.4  11.9  0.531  BOS  15.5  -0.3
# vince carter        2002-03  SG   1.7   8.2   7.3  0.532  TOR  28.1   1.7
# vincent yarbrough   2002-03  SG   2.2  15.1   6.8  0.446  DEN  17.3  -0.1
# vitaly potapenko    2002-03   C   1.2  19.1  13.0  0.492  SEA  15.2  -0.5
# vlade divac         2002-03   C   1.8  16.6  12.9  0.519  SAC  17.0   3.0
# vladimir radmanovic 2002-03  PF   1.8  12.3  10.0  0.508  SEA  20.0   0.6
# vladimir stepania   2002-03   C   1.5  12.4  20.1  0.454  MIA  16.4  -0.6
# voshon lenard       2002-03  SG   1.6  10.3   6.3  0.502  TOR  23.6   0.2
# wally szczerbiak    2002-03  SF   1.3   9.8   7.4  0.567  MIN  22.0   1.6
# walt williams       2002-03  SF   1.9   8.8   9.8  0.500  DAL  15.6   0.8
# walter mccarty      2002-03  SF   2.1  12.7   8.4  0.540  BOS  12.6   0.9
# wang zhizhi         2002-03   C   1.0  14.2  10.6  0.485  LAC  24.0  -0.5
# wesley person       2002-03  SG   1.1   8.0   5.6  0.565  MEM  16.2   0.8
# yao ming            2002-03   C   0.7  15.2  16.3  0.570  HOU  22.1   2.4
# zach randolph       2002-03  PF   1.7   9.6  15.9  0.555  POR  23.0   0.3
# zeljko rebraca      2002-03   C   0.7  14.9  11.2  0.596  DET  19.2  -0.1
# zendon hamilton     2002-03   C   4.5  14.5  19.0  0.510  TOR  26.2   0.0
# zydrunas ilgauskas  2002-03   C   1.2  13.5  14.1  0.516  CLE  27.8   0.7
#
#                               WS  WS/48       .1
#                     Season
# aaron mckie         2002-03  5.1  0.104 NaN  NaN
# aaron williams      2002-03  3.7  0.110 NaN  NaN
# adam harrington     2002-03  0.0  0.017 NaN  NaN
#                     2002-03 -0.1 -0.164 NaN  NaN
#                     2002-03  0.2  0.108 NaN  NaN
# adonal foyle        2002-03  4.0  0.106 NaN  NaN
# adrian griffin      2002-03  2.9  0.100 NaN  NaN
# aj guyton           2002-03 -0.1 -0.450 NaN  NaN
# al harrington       2002-03  3.9  0.075 NaN  NaN
# alan henderson      2002-03  2.6  0.083 NaN  NaN
# allan houston       2002-03  7.2  0.111 NaN  NaN
# allen iverson       2002-03  9.2  0.127 NaN  NaN
# alton ford          2002-03 -0.1 -0.113 NaN  NaN
# alvin williams      2002-03  5.5  0.101 NaN  NaN
# amal mccaskill      2002-03  0.0  0.015 NaN  NaN
# amare stoudemire    2002-03  6.2  0.116 NaN  NaN
# andre miller        2002-03  4.6  0.076 NaN  NaN
# andrei kirilenko    2002-03  9.2  0.199 NaN  NaN
# andrew declercq     2002-03  2.6  0.095 NaN  NaN
# anfernee hardaway   2002-03  2.3  0.062 NaN  NaN
# ansu sesay          2002-03 -0.1 -0.007 NaN  NaN
# antawn jamison      2002-03  8.5  0.126 NaN  NaN
# anthony carter      2002-03 -0.2 -0.012 NaN  NaN
# anthony goldwire    2002-03 -0.1 -0.035 NaN  NaN
#                     2002-03 -0.1 -0.069 NaN  NaN
#                     2002-03  0.0  0.016 NaN  NaN
# anthony johnson     2002-03  1.8  0.105 NaN  NaN
# anthony mason       2002-03  3.1  0.069 NaN  NaN
# anthony peeler      2002-03  3.4  0.072 NaN  NaN
# antoine rigaudeau   2002-03 -0.4 -0.192 NaN  NaN
# ...                          ...    ...  ..  ...
# tracy murray        2002-03 -0.2 -0.054 NaN  NaN
# travis best         2002-03  1.8  0.048 NaN  NaN
# travis knight       2002-03  0.2  0.040 NaN  NaN
# tremaine fowlkes    2002-03  1.2  0.102 NaN  NaN
# trenton hassell     2002-03 -0.1 -0.003 NaN  NaN
# troy hudson         2002-03  5.1  0.094 NaN  NaN
# troy murphy         2002-03  6.4  0.122 NaN  NaN
# tyrone hill         2002-03  1.4  0.049 NaN  NaN
#                     2002-03  0.6  0.036 NaN  NaN
#                     2002-03  0.7  0.072 NaN  NaN
# tyronn lue          2002-03  3.7  0.089 NaN  NaN
# tyson chandler      2002-03  3.9  0.102 NaN  NaN
# vin baker           2002-03  1.6  0.082 NaN  NaN
# vince carter        2002-03  4.2  0.136 NaN  NaN
# vincent yarbrough   2002-03  1.0  0.035 NaN  NaN
# vitaly potapenko    2002-03  0.2  0.027 NaN  NaN
# vlade divac         2002-03  7.0  0.141 NaN  NaN
# vladimir radmanovic 2002-03  2.7  0.068 NaN  NaN
# vladimir stepania   2002-03  2.9  0.089 NaN  NaN
# voshon lenard       2002-03  2.4  0.060 NaN  NaN
# wally szczerbiak    2002-03  5.2  0.135 NaN  NaN
# walt williams       2002-03  2.5  0.103 NaN  NaN
# walter mccarty      2002-03  4.1  0.101 NaN  NaN
# wang zhizhi         2002-03  0.1  0.014 NaN  NaN
# wesley person       2002-03  3.3  0.082 NaN  NaN
# yao ming            2002-03  8.7  0.176 NaN  NaN
# zach randolph       2002-03  4.8  0.177 NaN  NaN
# zeljko rebraca      2002-03  1.3  0.133 NaN  NaN
# zendon hamilton     2002-03  0.0  0.107 NaN  NaN
# zydrunas ilgauskas  2002-03  5.0  0.099 NaN  NaN
#
# [476 rows x 28 columns]

# %%
all_players_stats['advanced'].xs('2009-10', level=1, drop_level=False)['WS'].plot('hist')

# %%
all_players_career_winshare = all_players_stats['advanced'].xs('Career', level=1, drop_level=True)['WS']

# %%
all_players_career_winshare[all_players_career_winshare.index.str.contains('brian')]
# Out:
# brian cardinal      15.4
# brian cook          10.2
# brian davis          0.0
# brian evans          1.7
# brian grant         54.5
# brian heaney         0.2
# brian howard         0.9
# brian martin        -0.1
# brian oliver        -0.5
# brian quinnett       0.9
# brian roberts        7.4
# brian rowsom         2.4
# brian scalabrine     7.6
# brian shaw          23.8
# brian skinner       15.8
# brian taylor        46.8
# brian winters       38.6
# briante weber        0.3
# frankie brian       30.1
# Name: WS, dtype: float64

# %%
ax = all_players_career_winshare.plot('hist', ylim=(0, 2000), xlim=(-20, 300), bins=32, figsize=(12,9))

def annotate_ax(ax, player_name, height):
    label = player_name + ' (' + str(all_players_career_winshare[player_name]) + ')'
    ax.annotate(label,
                xycoords='data', # xy coord mode
                xy=(all_players_career_winshare[player_name], 0), # xy coord value
                textcoords='offset points', # text coord mode (in this case offset the text)
                xytext=(0, height), # text coord value
                rotation=45,
                verticalalignment='left',
                horizontalalignment='bottom')

annotate_ax(ax, 'kareem abdul-jabbar', 100)
annotate_ax(ax, 'michael jordan', 100)
annotate_ax(ax, 'larry bird', 100)
annotate_ax(ax, 'magic johnson', 100)
annotate_ax(ax, 'kobe bryant', 100)
annotate_ax(ax, 'mike bibby', 100)

annotate_ax(ax, 'lebron james', 10)
annotate_ax(ax, 'kevin durant', 10)
annotate_ax(ax, 'james harden', 10)
annotate_ax(ax, 'stephen curry', 10)
annotate_ax(ax, 'kawhi leonard', 10)
annotate_ax(ax, 'mike conley', 10)

    
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.set_xlabel('Career Win Shares')
ax.set_ylabel('Number of Players')

ax.set_xticks(range(0, 300, 25))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d642e67ea9ca> in <module>()
# ----> 1 ax = all_players_career_winshare.plot('hist', ylim=(0, 2000), xlim=(-20, 300), bins=32, figsize=(12,9))
#       2
#       3 def annotate_ax(ax, player_name, height):
#       4     label = player_name + ' (' + str(all_players_career_winshare[player_name]) + ')'
#       5     ax.annotate(label,
#
# NameError: name 'all_players_career_winshare' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

def annotate_ax(ax, data, player_name, height):
    label = player_name + ' (' + str(data[player_name]) + ')'
    ax.annotate(label,
                xycoords='data', # xy coord mode
                xy=(data[player_name], 0), # xy coord value
                textcoords='offset points', # text coord mode (in this case offset the text)
                xytext=(0, height), # text coord value
                rotation=45,
                verticalalignment='left',
                horizontalalignment='bottom')

def plot_player_stats(
    stat_type='totals', stat='PTS', year='Career', title='Histogram: NBA Career PTS', annotation_players=None):
    
    data = all_players_stats[stat_type].xs(year, level=1, drop_level=True)[stat]
    
    binwidth = 1000
    bins = range(math.floor(min(data)), math.ceil(max(data)) + binwidth, binwidth)
    
    plt.figure(figsize=(12,9))
    
    ax = plt.subplot(111)
    
    # Hide the right and top spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    # Only show ticks on the left and bottom spines
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')
    
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    
    plt.xlabel(str(year) + ' ' + stat, fontsize=16)
    plt.ylabel('count(Players)', fontsize=16)
    
#     data.plot('hist', bins=bins)

    plt.hist(data, color="#3F5D7D", bins=bins) 
    
    for (player, height) in annotation_players:
        annotate_ax(ax, data, player, height)

annotation_players = [
    'kobe bryant', 
    'michael jordan', 
    'yao ming',
    'kareem abdul-jabbar',
    'magic johnson',
    'larry bird',
]
plot_player_stats(annotation_players=annotation_players)
